# %% [markdown]
# ## Sufyan Ahmad
# ## 201980013
# ## Assignment 03

# %% [markdown]
# ###  This code segment clones the YOLOv5 repository, installs required packages, and sets up the environment for working with YOLOv5, including the necessary imports and environment configurations. It's a common sequence of steps to prepare for using a specific code repository or library.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# ### This command unzip -q ../Dataset.zip -d ../ is used to silently and quickly extract the contents of the "Dataset.zip" archive into the parent directory of the current working directory. This is a common way to unzip files from the command line, and it's particularly useful for automating tasks or managing datasets.

# %%
! unzip -q ../Dataset.zip -d ../
# Out:
# replace ../Dataset/images/train/1114371.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ### This command uses the 'detect.py' script to perform object detection using a YOLOv5 model. The model's weights are loaded from a specific location, and detection is carried out on a video source with certain configuration settings, such as input image size and confidence threshold. This command is useful for applying the trained model to perform object detection on videos or images

# %%
#Detect
# !python detect.py --weights runs/train/exp3/weights/last.pt  --img 640 --conf 0.25  --source ../video.mp4
# Out:
# detect: weights=['runs/train/exp3/weights/last.pt'], source=../video.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/2284) /content/video.mp4: 384x640 1 ship, 67.3ms
# video 1/1 (2/2284) /content/video.mp4: 384x640 1 ship, 8.0ms
# video 1/1 (3/2284) /content/video.mp4: 384x640 1 ship, 8.0ms
# video 1/1 (4/2284) /content/video.mp4: 384x640 1 ship, 20.2ms
# video 1/1 (5/2284) /content/video.mp4: 384x640 1 ship, 16.4ms
# ...

# %% [markdown]
# ### This command is instructing the train.py script to train a YOLOv5 object detection model using specific settings, such as image size, batch size, number of epochs, dataset configuration, initial weights, and potentially enabling caching during training. This is a common way to initiate the training process for machine learning models using command-line arguments.

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 50 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-210-gdd10481 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...
